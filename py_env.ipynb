# %% [markdown]
# # 🐍🐍🐍🐍🐍🐍  Python Hack Night   🐍🐍🐍🐍🐍🐍
#
#
#
# ## 👩‍🎤 Introduce yourself 👨‍🎤 or share a project!
#
# *"Some ideas"*
# * What's your programming experience?
# * Something non-programming related you did in the past week
# * What are you interested in learning?
# * Anything else you'd like to share
# ---
#
# #
# Before we begin:
# What is the terminal/command prompt?
# Where can python run?
#
#
# ## 🤖 Virtual Environments 🤖
# ---
#
#
# ### 🌮 _What it is_ 🌮
# - Isolated "environments" in your local machine
#
#
# ### ⁉️ [_Why tho_ ](http://i0.kym-cdn.com/entries/icons/original/000/022/978/yNlQWRM.jpg) ⁉️
# - Manage your various Python projects
#
#
# ### 🤔 _What it do_ 🤔
# - Keep your python projects separated from one another
# - Avoid mixing up python dependencies and dependency versions
#
#
# #### Prerequisites for understanding Python virtual environments:
# - a basic understanding of the operating system (OS)
# - a basic understanding of computer directories
# - understanding the concept of & need for [python modules/packages](https://www.learnpython.org/en/Modules_and_Packages)
# - understanding the Python organization's approach to [packaging( __Pip__ )](https://pypi.org/project/pip/)
# - ['requirements.txt' convention](https://stackoverflow.com/a/15593865/5788582)
# - ability to use [Google](http://bfy.tw/1Ek)
#
#
# #### Helpful for debugging Python virtual env-related issues:
# - familiarity with your command prompt(Windows) or terminal(MacOS/Linux)
# - understanding the concept of [relative/absolute paths](https://www.computerhope.com/issues/ch001708.htm) ([+1](https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f))
# - ability to use [Google](http://bfy.tw/1Ek)
#
# ---
#
# ### Cool, so what's the big deal?
# - Initial set up can be confusing/annoying
# because of differences between OS, versions, python[\*\*](#python2note) and also, choice of python tools in the wild (venv, virtualenv, virtualenvwrapper, pipenv, pip, etc.)
#
#
#
# ### Python Virtual Environments--A Brief History
# _Back then we used to use [that.](https://docs.python.org/3/tutorial/venv.html)_
#
#
# ### Python Virtual Environments--The Future
# _And now we use [this.](https://packaging.python.org/tutorials/managing-dependencies/)_
#
#
# _But __that__ is still 👌👌_.
#
#
# ---
#
#
# # Hack Night
# #### Objective:
# ##### Install pipenv and install Python packages
#
# 1) Make sure you have Python installed on your system
# 2) Test out Pip
# 3) Install Pipenv
# 4) Make a test directory
# 5) Start the environment
# 5) Install a python package into the environment
# 6) Exit the environment
#
#
#
# ## What you should aim for (re: py. virt. env.)
# ##### Get yourself accustomed to a basic python project workflow
# *...activate,doyour💩,deactivate...activate,doyour💩,deactivate...activate,doyour💩,deactivate...activate,doyour💩,deactivate...activate,doyour💩,deactivate...activate,doyour💩,deactivate...activate,doyour💩,deactivate...*
# - Creating a directory for your project
# - Starting(Activating) the virtual environment(Activation commands)
# - Keeping *that* particular project's dependencies isolated(Installation commands)
# - Exiting(Deactivating) the virtual environment(Deact. command)
#
#
# ### troubleshooting
# Copy the error message. Paste into a search engine.
#
# - When Copy/Pasting:
#     - keep only relevant keywords in the search
#     - remove your personal name, your personal directory names, etc.
#
# _Someone, at some point, has run into your error. The solution has been recorded in the internets. Just keep searching._ 🐠
# https://media.giphy.com/media/l2JdUhw8mMsaQxaAE/giphy.gif
#
#
# ### For your reference
#
# #### Just A FEW commands you'll use in the command line early on:
#
# _run these commands worry-free_
# `python --version` (print out the version of Python currently running)
# `pip --version` (print out the version of pip)
# `pip --help`
# `pipenv --version` (print out the version of Python currently running)
# `pip freeze` (list all the python packages for __current__ env)
# which, whereis, /win equiv
#
# _be very fucking worried_
# `pip install some_package_name`
# `pipenv shell`
# `pipenv install`
#
# _just kidding_
#
#
# ---
#
# 👻Python documentation(language and packaging):
# https://docs.python.org/3/
#
# 🍜Pipenv -- a tool to manage virtual environments && python packages at the same time:
# https://docs.pipenv.org/
#
# 🍲 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿 🍵🐍 🐙 🦀 🐡 🐠 🐟 🐬 🐳 🐋 🐊 🐅 🐆 🐘🐪 🐫 🦒 🐃 🐂 🐄 🐎 🐖 🐏 🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿🐑 🐐 🐕 🐩 🐈 🐓 🦃 🕊 🐇 🐁 🐀 🐿
#
# ---

# %% [markdown]
# <a id='python2note'></a>
# _Readme later._
# [\*\*](#python2note) - Python 2 has been "the Python" for many years. Python 3 is now stable enough that Python2 is being phased out from...everything. Still, you'll run into Python2 vs Python3 versioning issues often.
# Just be aware of the differences between python2 and python3 syntax, pip and pip3, your system's default python version.
#
# [\*\*](#note)

# %% [markdown]
# ## 👈 👆👉 👇🖕📴 See you guys next time! 👈 👆👉 👇🖕📴
